# %%
# !pip install ucimlrepo
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [ucimlrepo]
#    ---------------------------------------- 2/2 [ucimlrepo]
#
# ...

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = fetch_ucirepo(id=17)

X = dataset.data.features
y = dataset.data.targets

# %%
df = pd.concat([X, y], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   radius1             569 non-null    float64
#  1   texture1            569 non-null    float64
#  2   perimeter1          569 non-null    float64
#  3   area1               569 non-null    float64
#  4   smoothness1         569 non-null    float64
#  5   compactness1        569 non-null    float64
#  6   concavity1          569 non-null    float64
#  7   concave_points1     569 non-null    float64
#  8   symmetry1           569 non-null    float64
#  9   fractal_dimension1  569 non-null    float64
#  10  radius2             569 non-null    float64
#  11  texture2            569 non-null    float64
#  12  perimeter2          569 non-null    float64
#  13  area2               569 non-null    float64
#  14  smoothness2         569 non-null    float64
# ...

# %%
df.describe()
# Out:
#           radius1    texture1  perimeter1        area1  smoothness1  \
# count  569.000000  569.000000  569.000000   569.000000   569.000000
# mean    14.127292   19.289649   91.969033   654.889104     0.096360
# std      3.524049    4.301036   24.298981   351.914129     0.014064
# min      6.981000    9.710000   43.790000   143.500000     0.052630
# 25%     11.700000   16.170000   75.170000   420.300000     0.086370
# 50%     13.370000   18.840000   86.240000   551.100000     0.095870
# 75%     15.780000   21.800000  104.100000   782.700000     0.105300
# max     28.110000   39.280000  188.500000  2501.000000     0.163400
#
#        compactness1  concavity1  concave_points1   symmetry1  \
# count    569.000000  569.000000       569.000000  569.000000
# mean       0.104341    0.088799         0.048919    0.181162
# std        0.052813    0.079720         0.038803    0.027414
# min        0.019380    0.000000         0.000000    0.106000
# ...

# %%
plt.figure()
df["radius1"].hist(bins=20)
plt.title("Distribution of Mean Radius")
plt.show()

# %%
plt.figure()
sns.boxplot(x=df["area1"])
plt.title("Boxplot of Mean Area")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.rename(columns={"Diagnosis": "target"}, inplace=True)
print(df.columns)
# Out:
# Index(['radius1', 'texture1', 'perimeter1', 'area1', 'smoothness1',
#        'compactness1', 'concavity1', 'concave_points1', 'symmetry1',
#        'fractal_dimension1', 'radius2', 'texture2', 'perimeter2', 'area2',
#        'smoothness2', 'compactness2', 'concavity2', 'concave_points2',
#        'symmetry2', 'fractal_dimension2', 'radius3', 'texture3', 'perimeter3',
#        'area3', 'smoothness3', 'compactness3', 'concavity3', 'concave_points3',
#        'symmetry3', 'fractal_dimension3', 'target'],
#       dtype='object')

# %%
df["target"] = df["target"].map({"M": 1, "B": 0})

print("\nTarget value counts:")
print(df["target"].value_counts())
# Out:
# Target value counts:
# target
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
duplicate_count = df.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
print("\nFinal Dataset Info:")
df.info()
# Out:
# Final Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   radius1             569 non-null    float64
#  1   texture1            569 non-null    float64
#  2   perimeter1          569 non-null    float64
#  3   area1               569 non-null    float64
#  4   smoothness1         569 non-null    float64
#  5   compactness1        569 non-null    float64
#  6   concavity1          569 non-null    float64
#  7   concave_points1     569 non-null    float64
#  8   symmetry1           569 non-null    float64
#  9   fractal_dimension1  569 non-null    float64
#  10  radius2             569 non-null    float64
#  11  texture2            569 non-null    float64
#  12  perimeter2          569 non-null    float64
#  13  area2               569 non-null    float64
#  14  smoothness2         569 non-null    float64
# ...

# %%
print(df.isnull().sum())
# Out:
# radius1               0
# texture1              0
# perimeter1            0
# area1                 0
# smoothness1           0
# compactness1          0
# concavity1            0
# concave_points1       0
# symmetry1             0
# fractal_dimension1    0
# radius2               0
# texture2              0
# perimeter2            0
# area2                 0
# smoothness2           0
# compactness2          0
# concavity2            0
# concave_points2       0
# symmetry2             0
# fractal_dimension2    0
# radius3               0
# texture3              0
# perimeter3            0
# area3                 0
# smoothness3           0
# compactness3          0
# concavity3            0
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# target                0
# dtype: int64

# %%
Q1 = df["area1"].quantile(0.25)
Q3 = df["area1"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["area1"] < lower_bound) | (df["area1"] > upper_bound)]

print("Number of outliers in area1:", len(outliers))
print("Outliers in area1:", list(outliers["area1"]))
# Out:
# Number of outliers in area1: 25
# Outliers in area1: [1404.0, 1878.0, 1509.0, 1761.0, 1686.0, 2250.0, 1685.0, 2499.0, 1670.0, 1364.0, 1419.0, 1491.0, 1747.0, 2010.0, 1546.0, 1482.0, 1386.0, 1335.0, 1407.0, 1384.0, 2501.0, 1682.0, 1841.0, 1347.0, 1479.0]

# %%
df["area1"] = df["area1"].clip(lower_bound, upper_bound)

# %%
outliers_after = df[(df["area1"] < lower_bound) | (df["area1"] > upper_bound)]

print("Outliers after handling:", len(outliers_after))
# Out:
# Outliers after handling: 0

# %%
X = df.drop("target", axis=1)
y = df["target"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
scaled_df = pd.concat([X_scaled_df, y], axis=1)
scaled_df.head()
# Out:
#     radius1  texture1  perimeter1     area1  smoothness1  compactness1  \
# 0  1.097064 -2.073335    1.269934  1.184085     1.568466      3.283515
# 1  1.829821 -0.353632    1.685955  2.249396    -0.826962     -0.487072
# 2  1.579888  0.456187    1.566503  1.846217     0.942210      1.052926
# 3 -0.768909  0.253732   -0.592687 -0.831485     3.283553      3.402909
# 4  1.750297 -1.151816    1.776573  2.154338     0.280372      0.539340
#
#    concavity1  concave_points1  symmetry1  fractal_dimension1  ...  texture3  \
# 0    2.652874         2.532475   2.217515            2.255747  ... -1.359293
# 1   -0.023846         0.548144   0.001392           -0.868652  ... -0.369203
# 2    1.363478         2.037231   0.939685           -0.398008  ... -0.023974
# 3    1.915897         1.451707   2.867383            4.910919  ...  0.133984
# 4    1.371011         1.428493  -0.009560           -0.562450  ... -1.466770
#
#    perimeter3     area3  smoothness3  compactness3  concavity3  \
# ...

# %%
scaled_df.describe()
# Out:
#             radius1      texture1    perimeter1         area1   smoothness1  \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean  -1.373633e-16  6.868164e-17 -1.248757e-16  7.492542e-17 -8.366672e-16
# std    1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00 -1.984504e+00 -1.626699e+00 -3.112085e+00
# 25%   -6.893853e-01 -7.259631e-01 -6.919555e-01 -7.193810e-01 -7.109628e-01
# 50%   -2.150816e-01 -1.046362e-01 -2.359800e-01 -2.906340e-01 -3.489108e-02
# 75%    4.693926e-01  5.841756e-01  4.996769e-01  4.685234e-01  6.361990e-01
# max    3.971288e+00  4.651889e+00  3.976130e+00  2.250380e+00  4.770911e+00
#
#        compactness1    concavity1  concave_points1     symmetry1  \
# count  5.690000e+02  5.690000e+02     5.690000e+02  5.690000e+02
# mean   1.873136e-16  4.995028e-17    -4.995028e-17  1.748260e-16
# std    1.000880e+00  1.000880e+00     1.000880e+00  1.000880e+00
# ...

# %%
print(df.select_dtypes(include=["object"]).columns)
# Out:
# Index([], dtype='object')
